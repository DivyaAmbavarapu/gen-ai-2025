# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randint(0,100,10),columns=['Sales'])

# %%
df.head()
# Out:
#    Sales
# 0     67
# 1     62
# 2     91
# 3     82
# 4     21

# %%
df
# Out:
#    Sales
# 0     67
# 1     62
# 2     91
# 3     82
# 4     21
# 5     94
# 6     10
# 7     12
# 8      9
# 9     87

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure(figsize=(20,7))
plt.plot(df['Sales'],marker='o',color='#dc33ff',markerfacecolor='w',
         markeredgecolor='black',markeredgewidth=2,linewidth=10,alpha=0.9)
plt.xlabel("Index")
plt.ylabel("Sales")
plt.title("Sales vs Index")
plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
df=pd.DataFrame(np.random.randint(0,10,(10,5)),columns="A B C D E".split())

# %%
df
# Out:
#    A  B  C  D  E
# 0  5  9  7  2  9
# 1  7  9  3  8  2
# 2  6  1  0  9  6
# 3  9  1  1  6  1
# 4  3  3  3  9  4
# 5  2  5  8  7  8
# 6  2  6  4  6  8
# 7  9  5  7  4  0
# 8  6  5  6  7  2
# 9  1  1  5  2  4

# %%
plt.subplot(2,2,1)
plt.plot(df['A'],color='r')
plt.subplot(2,2,2)
plt.plot(df['B'],color='b')
plt.subplot(2,2,3)
plt.plot(df['C'],color='y')
plt.subplot(2,2,4)
plt.plot(df['D'])
plt.savefig("sample.png")

# %%
plt.subplot(4,2,1)
plt.plot(df['A'],color='r')

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------- ----------------- 4.5/8.1 MB 22.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 18.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 20.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------  2.6/2.7 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 10.2 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
# ...
