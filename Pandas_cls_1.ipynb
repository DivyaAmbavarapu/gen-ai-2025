# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame([1,2,3],columns=['number'],index=[2,3,4])
# Out:
#    number
# 2       1
# 3       2
# 4       3

# %%
df=pd.DataFrame(np.random.randint(0,100,(3,3)),columns="A B C".split(),index="P Q R".split())

# %%
df
# Out:
#     A   B   C
# P  57  83  23
# Q  93  66  55
# R  69  80  31

# %%
df=pd.DataFrame(np.random.randint(0,100,(10,5)))

# %%
data=[]
for i in range(1,11):
  data.append("student"+str(i))

# %%
data
# Out:
# ['student1',
#  'student2',
#  'student3',
#  'student4',
#  'student5',
#  'student6',
#  'student7',
#  'student8',
#  'student9',
#  'student10']

# %%
df.index=data

# %%
df
# Out:
#             0   1   2   3   4
# student1    3  10  44  59  43
# student2   54  77  14  96  71
# student3   57  29  11  67   4
# student4   87  99  99  82  35
# student5   71  16  27  81  65
# student6   86  40  83  40  86
# student7   42  78  61  16   4
# student8   45  82   2  87  63
# student9   86  87  68  31  82
# student10  16  46  45  38  72

# %%
data=[]
for i in range(1,6):
  data.append("subject"+str(i))

# %%
df.columns=data

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1          3        10        44        59        43
# student2         54        77        14        96        71
# student3         57        29        11        67         4
# student4         87        99        99        82        35
# student5         71        16        27        81        65
# student6         86        40        83        40        86
# student7         42        78        61        16         4
# student8         45        82         2        87        63
# student9         86        87        68        31        82
# student10        16        46        45        38        72

# %%
df.index
# Out:
# Index(['student1', 'student2', 'student3', 'student4', 'student5', 'student6',
#        'student7', 'student8', 'student9', 'student10'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['subject1', 'subject2', 'subject3', 'subject4', 'subject5'], dtype='object')

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1          3        10        44        59        43
# student2         54        77        14        96        71
# student3         57        29        11        67         4
# student4         87        99        99        82        35
# student5         71        16        27        81        65
# student6         86        40        83        40        86
# student7         42        78        61        16         4
# student8         45        82         2        87        63
# student9         86        87        68        31        82
# student10        16        46        45        38        72

# %%
df.shape
# Out:
# (10, 5)

# %%
df.values
# Out:
# array([[ 3, 10, 44, 59, 43],
#        [54, 77, 14, 96, 71],
#        [57, 29, 11, 67,  4],
#        [87, 99, 99, 82, 35],
#        [71, 16, 27, 81, 65],
#        [86, 40, 83, 40, 86],
#        [42, 78, 61, 16,  4],
#        [45, 82,  2, 87, 63],
#        [86, 87, 68, 31, 82],
#        [16, 46, 45, 38, 72]])

# %%
df.dtypes
# Out:
# subject1    int64
# subject2    int64
# subject3    int64
# subject4    int64
# subject5    int64
# dtype: object

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1          3        10        44        59        43
# student2         54        77        14        96        71
# student3         57        29        11        67         4
# student4         87        99        99        82        35
# student5         71        16        27        81        65
# student6         86        40        83        40        86
# student7         42        78        61        16         4
# student8         45        82         2        87        63
# student9         86        87        68        31        82
# student10        16        46        45        38        72

# %%
df.iloc[:3,-3:]
# Out:
#           subject3  subject4  subject5
# student1        44        59        43
# student2        14        96        71
# student3        11        67         4

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1          3        10        44        59        43
# student2         54        77        14        96        71
# student3         57        29        11        67         4
# student4         87        99        99        82        35
# student5         71        16        27        81        65
# student6         86        40        83        40        86
# student7         42        78        61        16         4
# student8         45        82         2        87        63
# student9         86        87        68        31        82
# student10        16        46        45        38        72

# %%
df.iloc[0:4,0:4]
# Out:
#           subject1  subject2  subject3  subject4
# student1         3        10        44        59
# student2        54        77        14        96
# student3        57        29        11        67
# student4        87        99        99        82

# %%
df.loc["student1":"student4","subject1":"subject4"]
# Out:
#           subject1  subject2  subject3  subject4
# student1         3        10        44        59
# student2        54        77        14        96
# student3        57        29        11        67
# student4        87        99        99        82

# %%
df["student1":"student2"]['subject1']
# Out:
# student1     3
# student2    54
# Name: subject1, dtype: int64

# %%
df=pd.read_excel("/content/Sample - Superstore_2024.xls")

# %%
df.shape
# Out:
# (10194, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df[df['Segment']=='Consumer']
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# 11         12  US-2021-130813 2021-01-06 2021-01-08    Second Class
# 14         15  US-2021-105417 2021-01-07 2021-01-12  Standard Class
# 15         16  US-2021-105417 2021-01-07 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10186   10187  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name   Segment Country/Region           City  \
# 0        DP-13000      Darren Powers  Consumer  United States        Houston
# 4        MB-18085         Mick Brown  Consumer  United States   Philadelphia
# 11       LS-17230   Lycoris Saunders  Consumer  United States    Los Angeles
# 14       VS-21820   Vivek Sundaresam  Consumer  United States     Huntsville
# 15       VS-21820   Vivek Sundaresam  Consumer  United States     Huntsville
# ...           ...                ...       ...            ...            ...
# 10186    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10189    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10191    JM-15580      Jill Matthias  Consumer  United States       Loveland
# 10192    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10193    HO-15230        Harry Olson  Consumer         Canada  Charlottetown
#
#        ... Postal Code   Region       Product ID         Category  \
# 0      ...       77095  Central  OFF-PA-10000174  Office Supplies
# 4      ...       19143     East  OFF-AR-10003478  Office Supplies
# 11     ...       90049     West  OFF-PA-10002005  Office Supplies
# 14     ...       77340  Central  FUR-FU-10004864        Furniture
# 15     ...       77340  Central  OFF-BI-10003708  Office Supplies
# ...    ...         ...      ...              ...              ...
# 10186  ...       10009     East  FUR-BO-10003441        Furniture
# 10189  ...       10009     East  OFF-BI-10003684  Office Supplies
# 10191  ...       80538     West  OFF-FA-10003472  Office Supplies
# 10192  ...       10009     East  TEC-PH-10004774       Technology
# 10193  ...         C0A     East  OFF-BI-10004040  Office Supplies
#
#       Sub-Category                                       Product Name  \
# 0            Paper  Message Book, Wirebound, Four 5 1/2" X 4" Form...
# 4              Art  Avery Hi-Liter EverBold Pen Style Fluorescent ...
# 11           Paper                                          Xerox 225
# 14     Furnishings  Howard Miller 14-1/2" Diameter Chrome Round Wa...
# 15         Binders  Acco Four Pocket Poly Ring Binder with Label H...
# ...            ...                                                ...
# 10186    Bookcases  Bush Westfield Collection Bookcases, Fully Ass...
# 10189      Binders               Wilson Jones Legal Size Ring Binders
# 10191    Fasteners                                Bagged Rubber Bands
# 10192       Phones                          Gear Head AU3700S Headset
# 10193      Binders                        Wilson Jones Impact Binders
#
#          Sales  Quantity  Discount   Profit
# 0       16.448         2       0.2   5.5512
# 4       19.536         3       0.2   4.8840
# 11      19.440         3       0.0   9.3312
# 14      76.728         3       0.6 -53.7096
# 15      10.430         7       0.8 -18.2525
# ...        ...       ...       ...      ...
# 10186  323.136         4       0.2  12.1176
# 10189   52.776         3       0.2  19.7910
# 10191    3.024         3       0.2  -0.6048
# 10192   90.930         7       0.0   2.7279
# 10193    3.024         3       0.2  -0.6048
#
# [5281 rows x 21 columns]

# %%
data=np.random.randint(0,10,10)

# %%
data
# Out:
# array([5, 3, 1, 0, 1, 4, 4, 8, 9, 6])

# %%
data[data<5]
# Out:
# array([3, 1, 0, 1, 4, 4])

# %%
df[(df['Region']=='West') | (df['Category']=='Office Supplies')]
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10188   10189  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# 1        PO-19195      Phillina Ober  Home Office  United States
# 2        PO-19195      Phillina Ober  Home Office  United States
# 3        PO-19195      Phillina Ober  Home Office  United States
# 4        MB-18085         Mick Brown     Consumer  United States
# ...           ...                ...          ...            ...
# 10188    EB-13975         Erica Bern    Corporate  United States
# 10189    PO-18865  Patrick O'Donnell     Consumer  United States
# 10190    EB-13975         Erica Bern    Corporate  United States
# 10191    JM-15580      Jill Matthias     Consumer  United States
# 10193    HO-15230        Harry Olson     Consumer         Canada
#
#                 City  ... Postal Code   Region       Product ID  \
# 0            Houston  ...       77095  Central  OFF-PA-10000174
# 1         Naperville  ...       60540  Central  OFF-BI-10004094
# 2         Naperville  ...       60540  Central  OFF-LA-10003223
# 3         Naperville  ...       60540  Central  OFF-ST-10002743
# 4       Philadelphia  ...       19143     East  OFF-AR-10003478
# ...              ...  ...         ...      ...              ...
# 10188      Fairfield  ...       94533     West  OFF-BI-10002103
# 10189  New York City  ...       10009     East  OFF-BI-10003684
# 10190      Fairfield  ...       94533     West  OFF-BI-10004632
# 10191       Loveland  ...       80538     West  OFF-FA-10003472
# 10193  Charlottetown  ...         C0A     East  OFF-BI-10004040
#
#               Category Sub-Category  \
# 0      Office Supplies        Paper
# 1      Office Supplies      Binders
# 2      Office Supplies       Labels
# 3      Office Supplies      Storage
# 4      Office Supplies          Art
# ...                ...          ...
# 10188  Office Supplies      Binders
# 10189  Office Supplies      Binders
# 10190  Office Supplies      Binders
# 10191  Office Supplies    Fasteners
# 10193  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0      Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1             GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                              Avery 508   11.784         3
# 3                          SAFCO Boltless Steel Shelving  272.736         3
# 4      Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
# ...                                                  ...      ...       ...
# 10188    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904         2
# 10189               Wilson Jones Legal Size Ring Binders   52.776         3
# 10190                                 GBC Binding covers   20.720         2
# 10191                                Bagged Rubber Bands    3.024         3
# 10193                        Wilson Jones Impact Binders    3.024         3
#
#        Discount   Profit
# 0           0.2   5.5512
# 1           0.8  -5.4870
# 2           0.2   4.2717
# 3           0.2 -64.7748
# 4           0.2   4.8840
# ...         ...      ...
# 10188       0.2   4.5188
# 10189       0.2  19.7910
# 10190       0.2   6.4750
# 10191       0.2  -0.6048
# 10193       0.2  -0.6048
#
# [7470 rows x 21 columns]

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df.select_dtypes(include='float').mean()
# Out:
# Sales       228.225854
# Discount      0.155385
# Profit       28.673417
# dtype: float64

# %%
df.select_dtypes(include='float').std()
# Out:
# Sales       619.906839
# Discount      0.206249
# Profit      232.465115
# dtype: float64

# %%
df.select_dtypes(include='float').min()
# Out:
# Sales          0.444
# Discount       0.000
# Profit     -6599.978
# dtype: float64

# %%
df.select_dtypes(include='float').max()
# Out:
# Sales       22638.480
# Discount        0.800
# Profit       8399.976
# dtype: float64

# %%
df.select_dtypes(include='float').var()
# Out:
# Sales       384284.488765
# Discount         0.042538
# Profit       54040.029718
# dtype: float64

# %%
df.select_dtypes(include='float').median()
# Out:
# Sales       53.91
# Discount     0.20
# Profit       8.69
# dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.25)
# Out:
# Sales       17.2200
# Discount     0.0000
# Profit       1.7608
# Name: 0.25, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.50)
# Out:
# Sales       53.91
# Discount     0.20
# Profit       8.69
# Name: 0.5, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.75)
# Out:
# Sales       209.500000
# Discount      0.200000
# Profit       29.297925
# Name: 0.75, dtype: float64

# %%
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2021-103800 2021-01-03 2021-01-07  Standard Class
# 1           2  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 2           3  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 3           4  US-2021-112326 2021-01-04 2021-01-08  Standard Class
# 4           5  US-2021-141817 2021-01-05 2021-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10190   10191  US-2024-115427 2024-12-30 2025-01-03  Standard Class
# 10191   10192  US-2024-156720 2024-12-30 2025-01-03  Standard Class
# 10192   10193  US-2024-143259 2024-12-30 2025-01-03  Standard Class
# 10193   10194  CA-2024-143500 2024-12-30 2025-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# 1        PO-19195      Phillina Ober  Home Office  United States
# 2        PO-19195      Phillina Ober  Home Office  United States
# 3        PO-19195      Phillina Ober  Home Office  United States
# 4        MB-18085         Mick Brown     Consumer  United States
# ...           ...                ...          ...            ...
# 10189    PO-18865  Patrick O'Donnell     Consumer  United States
# 10190    EB-13975         Erica Bern    Corporate  United States
# 10191    JM-15580      Jill Matthias     Consumer  United States
# 10192    PO-18865  Patrick O'Donnell     Consumer  United States
# 10193    HO-15230        Harry Olson     Consumer         Canada
#
#                 City  ... Postal Code   Region       Product ID  \
# 0            Houston  ...       77095  Central  OFF-PA-10000174
# 1         Naperville  ...       60540  Central  OFF-BI-10004094
# 2         Naperville  ...       60540  Central  OFF-LA-10003223
# 3         Naperville  ...       60540  Central  OFF-ST-10002743
# 4       Philadelphia  ...       19143     East  OFF-AR-10003478
# ...              ...  ...         ...      ...              ...
# 10189  New York City  ...       10009     East  OFF-BI-10003684
# 10190      Fairfield  ...       94533     West  OFF-BI-10004632
# 10191       Loveland  ...       80538     West  OFF-FA-10003472
# 10192  New York City  ...       10009     East  TEC-PH-10004774
# 10193  Charlottetown  ...         C0A     East  OFF-BI-10004040
#
#               Category Sub-Category  \
# 0      Office Supplies        Paper
# 1      Office Supplies      Binders
# 2      Office Supplies       Labels
# 3      Office Supplies      Storage
# 4      Office Supplies          Art
# ...                ...          ...
# 10189  Office Supplies      Binders
# 10190  Office Supplies      Binders
# 10191  Office Supplies    Fasteners
# 10192       Technology       Phones
# 10193  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0      Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1             GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                              Avery 508   11.784         3
# 3                          SAFCO Boltless Steel Shelving  272.736         3
# 4      Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
# ...                                                  ...      ...       ...
# 10189               Wilson Jones Legal Size Ring Binders   52.776         3
# 10190                                 GBC Binding covers   20.720         2
# 10191                                Bagged Rubber Bands    3.024         3
# 10192                          Gear Head AU3700S Headset   90.930         7
# 10193                        Wilson Jones Impact Binders    3.024         3
#
#        Discount   Profit
# 0           0.2   5.5512
# 1           0.8  -5.4870
# 2           0.2   4.2717
# 3           0.2 -64.7748
# 4           0.2   4.8840
# ...         ...      ...
# 10189       0.2  19.7910
# 10190       0.2   6.4750
# 10191       0.2  -0.6048
# 10192       0.0   2.7279
# 10193       0.2  -0.6048
#
# [10194 rows x 21 columns]

# %%
df.loc[:,["Sales","Region"]].groupby("Region").sum()
# Out:
#                Sales
# Region
# Central  503170.6728
# East     691828.1680
# South    391721.9050
# West     739813.6085

# %%
df.loc[:,["Sales","Region"]].groupby("Region").median()
# Out:
#           Sales
# Region
# Central  45.920
# East     52.536
# South    54.594
# West     60.840

# %%
df[df['Sales']>4000].shape
# Out:
# (41, 21)

# %%
df.shape
# Out:
# (10194, 21)
